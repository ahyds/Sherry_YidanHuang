# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from config import api_key
from pprint import pprint
import datetime

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities (emplty lists as container for data to generate later)
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)   # ? QUESTION: what is size meaning?
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count    #---? how to control number of cities ?
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# build result dataframe starting with city names
cities_pd = pd.DataFrame({
    "City":cities,
"Cloudiness":""
,"Country":""
,"Date":""
,"Humidity":""
,"Lat":""
,"Lng":""
,"Max Temp":""
,"Wind Speed":""
})
cities_pd.head()

# # Add columns for lat, lng, airport name, airport address, airport rating
# # Note that we used "" to specify initial entry.
# cities_pd["Cloudiness"] = ""
# cities_pd["Country"] = ""
# cities_pd["Date"] = ""
# cities_pd["Humidity"] = ""
# cities_pd["Lat"] = ""
# cities_pd["Lng"] = ""
# cities_pd["Max Temp"] = ""
# cities_pd["Wind Speed"] = ""


cities_pd.head()
# Out:
#              City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0         rikitea
# 1       taoudenni
# 2  vestmannaeyjar
# 3         mataura
# 4          tairua

# %%
# To enable print function with bold characters
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# Show start of processing
print('Beginning Data Retrieval')
print('-----------------------------------')
city_cnt = 1
set_cnt =1


# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_pd.iterrows():
    url = "http://api.openweathermap.org/data/2.5/weather?"
    city = row['City']
    
    # Build query URL
    query_url = url + "appid=" + api_key + "&q=" + city

    # make request
    weather_data = requests.get(query_url).json()
    
    try:
        # Retrieve data and update dataframe
        cities_pd.loc[index,"Cloudiness"] =weather_data['clouds']['all']
        cities_pd.loc[index,"Country"] =weather_data['sys']['country']
        cities_pd.loc[index,"Date"] =weather_data['dt']
        cities_pd.loc[index,"Humidity"] =weather_data['main']['humidity']
        cities_pd.loc[index,"Lat"] =weather_data['coord']['lat']
        cities_pd.loc[index,"Lng"] =weather_data['coord']['lon']
        cities_pd.loc[index,"Max Temp"] =weather_data['main'] ['temp_max']
        cities_pd.loc[index,"Wind Speed"] =weather_data['wind']['speed']
        print(f'Processing Record {city_cnt} of set {set_cnt} | {city}')
        
        # city cnt and set cnt rules
        if city_cnt<50:
            city_cnt += 1
        else:
            city_cnt = 1
            set_cnt += 1
        
    except (KeyError, IndexError):
        print ("City "+bcolors.BOLD + "not"+ bcolors.ENDC+" found. Skipping...")

# Show end of processing
print('-----------------------------------')
print('Data Retrieval Complete')
print('-----------------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------------
# Processing Record 1 of set 1 | rikitea
# Processing Record 2 of set 1 | taoudenni
# Processing Record 3 of set 1 | vestmannaeyjar
# Processing Record 4 of set 1 | mataura
# Processing Record 5 of set 1 | tairua
# Processing Record 6 of set 1 | chilca
# Processing Record 7 of set 1 | vaini
# Processing Record 8 of set 1 | albany
# Processing Record 9 of set 1 | esperance
# Processing Record 10 of set 1 | barrow
# Processing Record 11 of set 1 | codrington
# Processing Record 12 of set 1 | bandarbeyla
# Processing Record 13 of set 1 | sioux lookout
# Processing Record 14 of set 1 | aklavik
# Processing Record 15 of set 1 | cape town
# Processing Record 16 of set 1 | port alfred
# City not found. Skipping...
# Processing Record 17 of set 1 | jalu
# Processing Record 18 of set 1 | kandi
# City not found. Skipping...
# Processing Record 19 of set 1 | peleduy
# Processing Record 20 of set 1 | nyzhnya duvanka
# Processing Record 21 of set 1 | airai
# Processing Record 22 of set 1 | riosucio
# Processing Record 23 of set 1 | chapais
# Processing Record 24 of set 1 | voloshka
# City not found. Skipping...
# Processing Record 25 of set 1 | punta arenas
# Processing Record 26 of set 1 | ponta do sol
# Processing Record 27 of set 1 | mitsamiouli
# Processing Record 28 of set 1 | christchurch
# Processing Record 29 of set 1 | tabory
# Processing Record 30 of set 1 | chokurdakh
# City not found. Skipping...
# Processing Record 31 of set 1 | ushuaia
# Processing Record 32 of set 1 | port-gentil
# Processing Record 33 of set 1 | general roca
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of set 1 | guerrero negro
# Processing Record 35 of set 1 | hobart
# City not found. Skipping...
# Processing Record 36 of set 1 | jamestown
# Processing Record 37 of set 1 | ostrovnoy
# Processing Record 38 of set 1 | takab
# Processing Record 39 of set 1 | norman wells
# Processing Record 40 of set 1 | pueblo
# City not found. Skipping...
# Processing Record 41 of set 1 | mahebourg
# City not found. Skipping...
# Processing Record 42 of set 1 | hay river
# Processing Record 43 of set 1 | siraha
# Processing Record 44 of set 1 | severo-kurilsk
# Processing Record 45 of set 1 | kamalpur
# Processing Record 46 of set 1 | sur
# Processing Record 47 of set 1 | kapaa
# Processing Record 48 of set 1 | homer
# Processing Record 49 of set 1 | san mateo ixtatan
# Processing Record 50 of set 1 | anadyr
# Processing Record 1 of set 2 | kodiak
# Processing Record 2 of set 2 | qaanaaq
# Processing Record 3 of set 2 | puerto baquerizo moreno
# Processing Record 4 of set 2 | san isidro
# Processing Record 5 of set 2 | lebu
# Processing Record 6 of set 2 | dingle
# Processing Record 7 of set 2 | carnarvon
# Processing Record 8 of set 2 | hermanus
# Processing Record 9 of set 2 | sao joao da barra
# Processing Record 10 of set 2 | hasaki
# Processing Record 11 of set 2 | cotonou
# Processing Record 12 of set 2 | leshukonskoye
# Processing Record 13 of set 2 | puerto ayora
# Processing Record 14 of set 2 | namatanai
# Processing Record 15 of set 2 | bandar-e lengeh
# Processing Record 16 of set 2 | hervey bay
# Processing Record 17 of set 2 | umm lajj
# City not found. Skipping...
# Processing Record 18 of set 2 | ochakiv
# Processing Record 19 of set 2 | samarai
# Processing Record 20 of set 2 | clyde river
# Processing Record 21 of set 2 | fortuna
# Processing Record 22 of set 2 | nueva gorgona
# Processing Record 23 of set 2 | srednekolymsk
# Processing Record 24 of set 2 | bilma
# Processing Record 25 of set 2 | tuktoyaktuk
# Processing Record 26 of set 2 | yellowknife
# Processing Record 27 of set 2 | san policarpo
# Processing Record 28 of set 2 | zafra
# Processing Record 29 of set 2 | tuatapere
# City not found. Skipping...
# Processing Record 30 of set 2 | bluff
# Processing Record 31 of set 2 | alofi
# Processing Record 32 of set 2 | hedensted
# Processing Record 33 of set 2 | kloulklubed
# Processing Record 34 of set 2 | jaru
# Processing Record 35 of set 2 | linqiong
# Processing Record 36 of set 2 | sisimiut
# Processing Record 37 of set 2 | talnakh
# Processing Record 38 of set 2 | kommunar
# Processing Record 39 of set 2 | beisfjord
# City not found. Skipping...
# Processing Record 40 of set 2 | vanavara
# Processing Record 41 of set 2 | puri
# Processing Record 42 of set 2 | avera
# Processing Record 43 of set 2 | salalah
# Processing Record 44 of set 2 | cabo san lucas
# City not found. Skipping...
# Processing Record 45 of set 2 | hithadhoo
# Processing Record 46 of set 2 | new norfolk
# Processing Record 47 of set 2 | iqaluit
# Processing Record 48 of set 2 | nanortalik
# Processing Record 49 of set 2 | katsuura
# Processing Record 50 of set 2 | bredasdorp
# City not found. Skipping...
# Processing Record 1 of set 3 | tasiilaq
# Processing Record 2 of set 3 | aden
# Processing Record 3 of set 3 | leh
# Processing Record 4 of set 3 | constitucion
# Processing Record 5 of set 3 | grand gaube
# Processing Record 6 of set 3 | yingcheng
# Processing Record 7 of set 3 | ribeira grande
# Processing Record 8 of set 3 | colares
# Processing Record 9 of set 3 | thompson
# Processing Record 10 of set 3 | pevek
# Processing Record 11 of set 3 | butaritari
# Processing Record 12 of set 3 | tolaga bay
# Processing Record 13 of set 3 | mpika
# Processing Record 14 of set 3 | east london
# Processing Record 15 of set 3 | mahabad
# Processing Record 16 of set 3 | busselton
# Processing Record 17 of set 3 | lompoc
# Processing Record 18 of set 3 | petropavlovsk-kamchatskiy
# Processing Record 19 of set 3 | avarua
# Processing Record 20 of set 3 | souillac
# Processing Record 21 of set 3 | radhan
# Processing Record 22 of set 3 | hudson bay
# Processing Record 23 of set 3 | husavik
# Processing Record 24 of set 3 | kiunga
# Processing Record 25 of set 3 | castro
# Processing Record 26 of set 3 | kishi
# Processing Record 27 of set 3 | touros
# Processing Record 28 of set 3 | ijui
# Processing Record 29 of set 3 | sehithwa
# Processing Record 30 of set 3 | eregli
# Processing Record 31 of set 3 | atuona
# Processing Record 32 of set 3 | nurobod
# Processing Record 33 of set 3 | saint george
# Processing Record 34 of set 3 | rubik
# Processing Record 35 of set 3 | margate
# Processing Record 36 of set 3 | dikson
# Processing Record 37 of set 3 | imelda
# Processing Record 38 of set 3 | westport
# Processing Record 39 of set 3 | ancud
# Processing Record 40 of set 3 | moquegua
# City not found. Skipping...
# Processing Record 41 of set 3 | kikwit
# Processing Record 42 of set 3 | beringovskiy
# Processing Record 43 of set 3 | yar-sale
# Processing Record 44 of set 3 | vardo
# Processing Record 45 of set 3 | nelson bay
# Processing Record 46 of set 3 | vostok
# Processing Record 47 of set 3 | koutiala
# Processing Record 48 of set 3 | laguna
# Processing Record 49 of set 3 | susaki
# Processing Record 50 of set 3 | ergani
# Processing Record 1 of set 4 | mahibadhoo
# Processing Record 2 of set 4 | nagaur
# Processing Record 3 of set 4 | saint anthony
# Processing Record 4 of set 4 | safety harbor
# Processing Record 5 of set 4 | tilichiki
# Processing Record 6 of set 4 | berezovyy
# Processing Record 7 of set 4 | mosquera
# Processing Record 8 of set 4 | kisangani
# Processing Record 9 of set 4 | rocha
# Processing Record 10 of set 4 | hilo
# Processing Record 11 of set 4 | metro
# Processing Record 12 of set 4 | bourail
# Processing Record 13 of set 4 | kano
# Processing Record 14 of set 4 | muros
# Processing Record 15 of set 4 | saskylakh
# Processing Record 16 of set 4 | bonavista
# Processing Record 17 of set 4 | taltal
# Processing Record 18 of set 4 | khatanga
# Processing Record 19 of set 4 | araceli
# Processing Record 20 of set 4 | morgan city
# Processing Record 21 of set 4 | san cristobal
# Processing Record 22 of set 4 | saint-philippe
# Processing Record 23 of set 4 | hualmay
# Processing Record 24 of set 4 | sola
# Processing Record 25 of set 4 | paragould
# Processing Record 26 of set 4 | cidreira
# Processing Record 27 of set 4 | arraial do cabo
# Processing Record 28 of set 4 | nynashamn
# Processing Record 29 of set 4 | presidencia roque saenz pena
# City not found. Skipping...
# Processing Record 30 of set 4 | myrtle beach
# Processing Record 31 of set 4 | ahipara
# Processing Record 32 of set 4 | santa maria
# Processing Record 33 of set 4 | plouzane
# Processing Record 34 of set 4 | bogale
# Processing Record 35 of set 4 | sakaiminato
# Processing Record 36 of set 4 | mana
# Processing Record 37 of set 4 | mangrol
# Processing Record 38 of set 4 | port augusta
# Processing Record 39 of set 4 | pizarro
# Processing Record 40 of set 4 | maragogi
# Processing Record 41 of set 4 | kaitangata
# Processing Record 42 of set 4 | nikolskoye
# Processing Record 43 of set 4 | sitka
# Processing Record 44 of set 4 | waingapu
# Processing Record 45 of set 4 | calama
# Processing Record 46 of set 4 | kruisfontein
# Processing Record 47 of set 4 | volot
# Processing Record 48 of set 4 | olean
# Processing Record 49 of set 4 | kishtwar
# City not found. Skipping...
# Processing Record 50 of set 4 | deyang
# Processing Record 1 of set 5 | marystown
# Processing Record 2 of set 5 | upernavik
# Processing Record 3 of set 5 | tiksi
# City not found. Skipping...
# Processing Record 4 of set 5 | cherskiy
# Processing Record 5 of set 5 | bela vista
# Processing Record 6 of set 5 | klaksvik
# Processing Record 7 of set 5 | victoria
# Processing Record 8 of set 5 | leningradskiy
# Processing Record 9 of set 5 | ossora
# Processing Record 10 of set 5 | vila
# Processing Record 11 of set 5 | ayan
# Processing Record 12 of set 5 | luderitz
# Processing Record 13 of set 5 | vikindu
# Processing Record 14 of set 5 | te anau
# Processing Record 15 of set 5 | lianzhou
# City not found. Skipping...
# Processing Record 16 of set 5 | namtsy
# Processing Record 17 of set 5 | nakhon si thammarat
# Processing Record 18 of set 5 | campina grande do sul
# Processing Record 19 of set 5 | bethel
# Processing Record 20 of set 5 | ambon
# Processing Record 21 of set 5 | bambous virieux
# Processing Record 22 of set 5 | nishihara
# Processing Record 23 of set 5 | west bay
# Processing Record 24 of set 5 | davila
# Processing Record 25 of set 5 | never
# Processing Record 26 of set 5 | prado
# Processing Record 27 of set 5 | tautira
# Processing Record 28 of set 5 | quatre cocos
# Processing Record 29 of set 5 | flinders
# Processing Record 30 of set 5 | yumen
# Processing Record 31 of set 5 | sault sainte marie
# Processing Record 32 of set 5 | port elizabeth
# Processing Record 33 of set 5 | nuevo progreso
# Processing Record 34 of set 5 | bagdarin
# Processing Record 35 of set 5 | roald
# Processing Record 36 of set 5 | nyurba
# Processing Record 37 of set 5 | alekseyevka
# Processing Record 38 of set 5 | port lincoln
# Processing Record 39 of set 5 | bonfim
# City not found. Skipping...
# Processing Record 40 of set 5 | port macquarie
# Processing Record 41 of set 5 | hanyang
# Processing Record 42 of set 5 | visby
# City not found. Skipping...
# Processing Record 43 of set 5 | sabanalarga
# Processing Record 44 of set 5 | blyznyuky
# Processing Record 45 of set 5 | gornopravdinsk
# Processing Record 46 of set 5 | blagoyevo
# Processing Record 47 of set 5 | mar del plata
# City not found. Skipping...
# Processing Record 48 of set 5 | zhigansk
# Processing Record 49 of set 5 | kati
# Processing Record 50 of set 5 | kawalu
# Processing Record 1 of set 6 | kahului
# Processing Record 2 of set 6 | fairbanks
# Processing Record 3 of set 6 | meulaboh
# Processing Record 4 of set 6 | tawang
# Processing Record 5 of set 6 | cordoba
# Processing Record 6 of set 6 | bolu
# Processing Record 7 of set 6 | ketchikan
# City not found. Skipping...
# Processing Record 8 of set 6 | yaring
# Processing Record 9 of set 6 | amazar
# City not found. Skipping...
# Processing Record 10 of set 6 | whitehorse
# Processing Record 11 of set 6 | banda aceh
# Processing Record 12 of set 6 | matagami
# Processing Record 13 of set 6 | kutum
# Processing Record 14 of set 6 | nanakuli
# Processing Record 15 of set 6 | wamba
# Processing Record 16 of set 6 | porto novo
# Processing Record 17 of set 6 | gigmoto
# Processing Record 18 of set 6 | aldan
# Processing Record 19 of set 6 | norsup
# Processing Record 20 of set 6 | kupang
# Processing Record 21 of set 6 | nykoping
# Processing Record 22 of set 6 | sechura
# City not found. Skipping...
# Processing Record 23 of set 6 | vanimo
# Processing Record 24 of set 6 | praia
# Processing Record 25 of set 6 | mayakonda
# Processing Record 26 of set 6 | inuvik
# Processing Record 27 of set 6 | hobyo
# Processing Record 28 of set 6 | necochea
# City not found. Skipping...
# Processing Record 29 of set 6 | tamworth
# Processing Record 30 of set 6 | longyearbyen
# Processing Record 31 of set 6 | iquique
# Processing Record 32 of set 6 | cisterna
# Processing Record 33 of set 6 | taua
# Processing Record 34 of set 6 | frutal
# Processing Record 35 of set 6 | umm kaddadah
# Processing Record 36 of set 6 | afyonkarahisar
# Processing Record 37 of set 6 | amapa
# Processing Record 38 of set 6 | alekseyevsk
# Processing Record 39 of set 6 | skjold
# Processing Record 40 of set 6 | henties bay
# Processing Record 41 of set 6 | washougal
# Processing Record 42 of set 6 | altay
# Processing Record 43 of set 6 | puerto leguizamo
# Processing Record 44 of set 6 | san patricio
# Processing Record 45 of set 6 | la grande
# City not found. Skipping...
# Processing Record 46 of set 6 | gazli
# Processing Record 47 of set 6 | yatou
# Processing Record 48 of set 6 | saint-denis
# Processing Record 49 of set 6 | pacific grove
# Processing Record 50 of set 6 | camalu
# Processing Record 1 of set 7 | kavaratti
# Processing Record 2 of set 7 | ozernovskiy
# Processing Record 3 of set 7 | nome
# Processing Record 4 of set 7 | herran
# Processing Record 5 of set 7 | lavrentiya
# Processing Record 6 of set 7 | mudanjiang
# Processing Record 7 of set 7 | youghal
# Processing Record 8 of set 7 | dong hoi
# City not found. Skipping...
# Processing Record 9 of set 7 | songjianghe
# Processing Record 10 of set 7 | bathsheba
# Processing Record 11 of set 7 | dubti
# City not found. Skipping...
# Processing Record 12 of set 7 | dunedin
# Processing Record 13 of set 7 | natal
# Processing Record 14 of set 7 | dusti
# Processing Record 15 of set 7 | jawhar
# City not found. Skipping...
# Processing Record 16 of set 7 | guhagar
# Processing Record 17 of set 7 | shihezi
# Processing Record 18 of set 7 | poum
# Processing Record 19 of set 7 | faanui
# Processing Record 20 of set 7 | georgetown
# Processing Record 21 of set 7 | yulara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of set 7 | sandwick
# Processing Record 23 of set 7 | safranbolu
# Processing Record 24 of set 7 | ternuvate
# Processing Record 25 of set 7 | muzhi
# City not found. Skipping...
# Processing Record 26 of set 7 | bhag
# Processing Record 27 of set 7 | port keats
# City not found. Skipping...
# Processing Record 28 of set 7 | chuy
# Processing Record 29 of set 7 | jinxiang
# Processing Record 30 of set 7 | lethem
# Processing Record 31 of set 7 | banamba
# Processing Record 32 of set 7 | russell
# Processing Record 33 of set 7 | khani
# Processing Record 34 of set 7 | caraquet
# Processing Record 35 of set 7 | bithur
# City not found. Skipping...
# Processing Record 36 of set 7 | aguimes
# Processing Record 37 of set 7 | kavieng
# Processing Record 38 of set 7 | los alamos
# Processing Record 39 of set 7 | lubliniec
# Processing Record 40 of set 7 | bitkine
# Processing Record 41 of set 7 | kidal
# Processing Record 42 of set 7 | lagoa
# Processing Record 43 of set 7 | hibbing
# Processing Record 44 of set 7 | san antonio
# Processing Record 45 of set 7 | torbay
# Processing Record 46 of set 7 | walvis bay
# Processing Record 47 of set 7 | broome
# Processing Record 48 of set 7 | gubkinskiy
# Processing Record 49 of set 7 | hohhot
# Processing Record 50 of set 7 | pandan niog
# Processing Record 1 of set 8 | saint-augustin
# Processing Record 2 of set 8 | cassia
# Processing Record 3 of set 8 | los llanos de aridane
# Processing Record 4 of set 8 | paamiut
# Processing Record 5 of set 8 | naron
# Processing Record 6 of set 8 | college
# Processing Record 7 of set 8 | vanderbijlpark
# City not found. Skipping...
# Processing Record 8 of set 8 | manokwari
# Processing Record 9 of set 8 | kalmunai
# Processing Record 10 of set 8 | xai-xai
# Processing Record 11 of set 8 | acapulco
# Processing Record 12 of set 8 | arkhangelsk
# Processing Record 13 of set 8 | vaitape
# Processing Record 14 of set 8 | auki
# Processing Record 15 of set 8 | broken hill
# Processing Record 16 of set 8 | tigil
# Processing Record 17 of set 8 | ulagan
# Processing Record 18 of set 8 | okhtyrka
# Processing Record 19 of set 8 | abu dhabi
# Processing Record 20 of set 8 | cayenne
# Processing Record 21 of set 8 | mahon
# Processing Record 22 of set 8 | ballyshannon
# Processing Record 23 of set 8 | kenora
# Processing Record 24 of set 8 | novoagansk
# Processing Record 25 of set 8 | teeli
# Processing Record 26 of set 8 | beinamar
# Processing Record 27 of set 8 | libreville
# Processing Record 28 of set 8 | vila franca do campo
# Processing Record 29 of set 8 | tutoia
# Processing Record 30 of set 8 | plettenberg bay
# Processing Record 31 of set 8 | shimoda
# Processing Record 32 of set 8 | tsiroanomandidy
# Processing Record 33 of set 8 | lashio
# Processing Record 34 of set 8 | albion
# City not found. Skipping...
# Processing Record 35 of set 8 | lata
# Processing Record 36 of set 8 | abu samrah
# Processing Record 37 of set 8 | narsaq
# City not found. Skipping...
# Processing Record 38 of set 8 | tazovskiy
# Processing Record 39 of set 8 | beyneu
# City not found. Skipping...
# Processing Record 40 of set 8 | felanitx
# Processing Record 41 of set 8 | karratha
# Processing Record 42 of set 8 | khuzhir
# Processing Record 43 of set 8 | koslan
# Processing Record 44 of set 8 | zhangjiakou
# Processing Record 45 of set 8 | bambanglipuro
# Processing Record 46 of set 8 | harper
# Processing Record 47 of set 8 | havoysund
# Processing Record 48 of set 8 | pangody
# Processing Record 49 of set 8 | tadine
# Processing Record 50 of set 8 | rajmahal
# City not found. Skipping...
# Processing Record 1 of set 9 | opuwo
# City not found. Skipping...
# Processing Record 2 of set 9 | omaruru
# Processing Record 3 of set 9 | sandpoint
# Processing Record 4 of set 9 | rio grande
# Processing Record 5 of set 9 | nizhnyaya omka
# Processing Record 6 of set 9 | pabianice
# Processing Record 7 of set 9 | chicama
# Processing Record 8 of set 9 | ternate
# Processing Record 9 of set 9 | deputatskiy
# Processing Record 10 of set 9 | ganzhou
# Processing Record 11 of set 9 | fort nelson
# Processing Record 12 of set 9 | rawson
# Processing Record 13 of set 9 | sistranda
# Processing Record 14 of set 9 | eureka
# Processing Record 15 of set 9 | shangzhi
# Processing Record 16 of set 9 | varamin
# Processing Record 17 of set 9 | merauke
# City not found. Skipping...
# Processing Record 18 of set 9 | kuantan
# Processing Record 19 of set 9 | thunder bay
# Processing Record 20 of set 9 | negombo
# Processing Record 21 of set 9 | jumla
# Processing Record 22 of set 9 | xinan
# Processing Record 23 of set 9 | awbari
# Processing Record 24 of set 9 | hofn
# Processing Record 25 of set 9 | shenjiamen
# Processing Record 26 of set 9 | wanaka
# Processing Record 27 of set 9 | san vicente
# Processing Record 28 of set 9 | exeter
# Processing Record 29 of set 9 | mehamn
# Processing Record 30 of set 9 | sao jose da laje
# Processing Record 31 of set 9 | geraldton
# Processing Record 32 of set 9 | kapit
# Processing Record 33 of set 9 | batagay
# Processing Record 34 of set 9 | chichimila
# Processing Record 35 of set 9 | beloha
# Processing Record 36 of set 9 | mogok
# Processing Record 37 of set 9 | manggar
# Processing Record 38 of set 9 | tiarei
# Processing Record 39 of set 9 | bosaso
# City not found. Skipping...
# Processing Record 40 of set 9 | evensk
# Processing Record 41 of set 9 | baruun-urt
# City not found. Skipping...
# Processing Record 42 of set 9 | pisco
# Processing Record 43 of set 9 | campbell river
# Processing Record 44 of set 9 | monrovia
# Processing Record 45 of set 9 | grindavik
# Processing Record 46 of set 9 | miguel auza
# Processing Record 47 of set 9 | takoradi
# Processing Record 48 of set 9 | san quintin
# Processing Record 49 of set 9 | presidente olegario
# Processing Record 50 of set 9 | mareeba
# Processing Record 1 of set 10 | werneck
# Processing Record 2 of set 10 | rio gallegos
# City not found. Skipping...
# Processing Record 3 of set 10 | forio
# Processing Record 4 of set 10 | camacha
# Processing Record 5 of set 10 | arman
# City not found. Skipping...
# Processing Record 6 of set 10 | sorland
# Processing Record 7 of set 10 | naliya
# Processing Record 8 of set 10 | naze
# Processing Record 9 of set 10 | kaa-khem
# Processing Record 10 of set 10 | kraslava
# Processing Record 11 of set 10 | radaur
# Processing Record 12 of set 10 | tura
# Processing Record 13 of set 10 | basmat
# Processing Record 14 of set 10 | viedma
# Processing Record 15 of set 10 | brae
# Processing Record 16 of set 10 | baykit
# Processing Record 17 of set 10 | vung tau
# Processing Record 18 of set 10 | sept-iles
# Processing Record 19 of set 10 | ilulissat
# Processing Record 20 of set 10 | chunskiy
# City not found. Skipping...
# Processing Record 21 of set 10 | gladstone
# Processing Record 22 of set 10 | khargone
# Processing Record 23 of set 10 | sao filipe
# Processing Record 24 of set 10 | tacuarembo
# Processing Record 25 of set 10 | qaqortoq
# Processing Record 26 of set 10 | labuhan
# Processing Record 27 of set 10 | kostino
# Processing Record 28 of set 10 | ewo
# Processing Record 29 of set 10 | bilibino
# Processing Record 30 of set 10 | denpasar
# Processing Record 31 of set 10 | hidrolandia
# Processing Record 32 of set 10 | launceston
# Processing Record 33 of set 10 | havre-saint-pierre
# Processing Record 34 of set 10 | marsh harbour
# Processing Record 35 of set 10 | shache
# Processing Record 36 of set 10 | dakoro
# Processing Record 37 of set 10 | nantucket
# Processing Record 38 of set 10 | at-bashi
# City not found. Skipping...
# Processing Record 39 of set 10 | mesaria
# Processing Record 40 of set 10 | prince rupert
# Processing Record 41 of set 10 | biga
# Processing Record 42 of set 10 | charcas
# Processing Record 43 of set 10 | port hedland
# Processing Record 44 of set 10 | cabinda
# Processing Record 45 of set 10 | gat
# Processing Record 46 of set 10 | lorengau
# Processing Record 47 of set 10 | ocala
# Processing Record 48 of set 10 | keti bandar
# Processing Record 49 of set 10 | talara
# Processing Record 50 of set 10 | kieta
# Processing Record 1 of set 11 | ermelo
# Processing Record 2 of set 11 | murgab
# Processing Record 3 of set 11 | coari
# Processing Record 4 of set 11 | khandyga
# Processing Record 5 of set 11 | olga
# Processing Record 6 of set 11 | lahad datu
# Processing Record 7 of set 11 | santiago del estero
# Processing Record 8 of set 11 | honiara
# Processing Record 9 of set 11 | aberystwyth
# Processing Record 10 of set 11 | capannori
# Processing Record 11 of set 11 | medea
# Processing Record 12 of set 11 | ambato
# Processing Record 13 of set 11 | la ronge
# Processing Record 14 of set 11 | kirovskiy
# Processing Record 15 of set 11 | cuijk
# Processing Record 16 of set 11 | peniche
# Processing Record 17 of set 11 | bodden town
# Processing Record 18 of set 11 | coahuayana
# Processing Record 19 of set 11 | sibolga
# Processing Record 20 of set 11 | talcahuano
# Processing Record 21 of set 11 | nara
# Processing Record 22 of set 11 | fallon
# Processing Record 23 of set 11 | ryotsu
# Processing Record 24 of set 11 | clovis
# Processing Record 25 of set 11 | kosa
# Processing Record 26 of set 11 | ahuimanu
# Processing Record 27 of set 11 | alyangula
# Processing Record 28 of set 11 | tual
# Processing Record 29 of set 11 | oskarshamn
# Processing Record 30 of set 11 | cohoes
# City not found. Skipping...
# Processing Record 31 of set 11 | sangmelima
# Processing Record 32 of set 11 | bara
# Processing Record 33 of set 11 | markala
# Processing Record 34 of set 11 | swan hill
# Processing Record 35 of set 11 | champoton
# City not found. Skipping...
# Processing Record 36 of set 11 | atasu
# Processing Record 37 of set 11 | deori
# Processing Record 38 of set 11 | manga
# Processing Record 39 of set 11 | binzhou
# Processing Record 40 of set 11 | tarusa
# Processing Record 41 of set 11 | dickinson
# Processing Record 42 of set 11 | mount gambier
# Processing Record 43 of set 11 | tamiahua
# Processing Record 44 of set 11 | nichinan
# Processing Record 45 of set 11 | bukama
# Processing Record 46 of set 11 | mogadishu
# Processing Record 47 of set 11 | itoman
# Processing Record 48 of set 11 | pouebo
# Processing Record 49 of set 11 | kozhva
# Processing Record 50 of set 11 | minuri
# Processing Record 1 of set 12 | tessalit
# Processing Record 2 of set 12 | remedios
# Processing Record 3 of set 12 | tingo maria
# -----------------------------------
# Data Retrieval Complete
# -----------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export to .csv
cities_pd.to_csv(output_data_file)

# Display data frame
cities_pd.count()
# Out:
# City          603
# Cloudiness    603
# Country       603
# Date          603
# Humidity      603
# Lat           603
# Lng           603
# Max Temp      603
# Wind Speed    603
# dtype: int64

# %%
# Visualise data
cities_pd.head()
# Out:
#              City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0         rikitea         16      PF  1562977499       80 -23.12 -134.97
# 1       taoudenni          0      ML  1562977499       14  22.68   -3.98
# 2  vestmannaeyjar         98      IS  1562977499       93  63.44  -20.27
# 3         mataura        100      NZ  1562977500       70 -46.19  168.86
# 4          tairua          2      NZ  1562977500       76 -37.02  175.85
#
#   Max Temp Wind Speed
# 0    296.5       7.34
# 1      309       4.76
# 2    284.8       3.57
# 3   287.04       0.45
# 4   290.93       4.47

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Out:
# '2019-07-12'

# %%
x = pd.to_numeric(cities_pd['Lat'])
y = cities_pd['Max Temp']

plt.scatter(x, y, marker="o" ,  edgecolors="black", c='coral', alpha =0.85, linewidth=[0.79])


# Generate date
datetime.datetime.now().date()
current_day = datetime.datetime.now().date()
c_day = current_day.isoformat()

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs. Max Temperature ({c_day})')

plt.grid()

# Save Figure
plt.savefig('W1.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# x = pd.to_numeric(cities_pd['Lat'])
y = cities_pd['Humidity']

plt.scatter(x, y, marker="o" ,  edgecolors="black", c='coral', alpha =0.85, linewidth=[0.79])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs. Max Temperature ({c_day})')

plt.grid()

# Save Figure
plt.savefig('W2.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# x = pd.to_numeric(cities_pd['Lat'])
y = cities_pd['Cloudiness']

plt.scatter(x, y, marker="o" ,  edgecolors="black", c='coral', alpha =0.85, linewidth=[0.79])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs. Max Temperature ({c_day})')

plt.grid()

# Save Figure
plt.savefig('W3.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# x = pd.to_numeric(cities_pd['Lat'])
y = cities_pd['Wind Speed']

plt.scatter(x, y, marker="o" ,  edgecolors="black", c='coral', alpha =0.85, linewidth=[0.79])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs. Max Temperature ({c_day})')

plt.grid()

# Save Figure
plt.savefig('W4.png')

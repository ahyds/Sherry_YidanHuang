# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from config import api_key
from pprint import pprint

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities (emplty lists as container for data to generate later)
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)   # ? QUESTION: what is size meaning?
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count    #---? how to control number of cities ?
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# build result dataframe starting with city names
cities_pd = pd.DataFrame({
    "City":cities,
"Cloudiness":""
,"Country":""
,"Date":""
,"Humidity":""
,"Lat":""
,"Lng":""
,"Max Temp":""
,"Wind Speed":""
})
cities_pd.head()

# # Add columns for lat, lng, airport name, airport address, airport rating
# # Note that we used "" to specify initial entry.
# cities_pd["Cloudiness"] = ""
# cities_pd["Country"] = ""
# cities_pd["Date"] = ""
# cities_pd["Humidity"] = ""
# cities_pd["Lat"] = ""
# cities_pd["Lng"] = ""
# cities_pd["Max Temp"] = ""
# cities_pd["Wind Speed"] = ""


cities_pd.head()
# Out:
#         City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0       naze
# 1      alofi
# 2  busselton
# 3    rikitea
# 4  cape town

# %%
# To enable print function with bold characters
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# Show start of processing
print('Beginning Data Retrieval')
print('-----------------------------------')
city_cnt = 1
set_cnt =1


# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_pd.iterrows():
    url = "http://api.openweathermap.org/data/2.5/weather?"
    city = row['City']
    
    # Build query URL
    query_url = url + "appid=" + api_key + "&q=" + city

    # make request
    weather_data = requests.get(query_url).json()
    
    try:
        # Retrieve data and update dataframe
        cities_pd.loc[index,"Cloudiness"] =weather_data['clouds']['all']
        cities_pd.loc[index,"Country"] =weather_data['sys']['country']
        cities_pd.loc[index,"Date"] =weather_data['dt']
        cities_pd.loc[index,"Humidity"] =weather_data['main']['humidity']
        cities_pd.loc[index,"Lat"] =weather_data['coord']['lat']
        cities_pd.loc[index,"Lng"] =weather_data['coord']['lon']
        cities_pd.loc[index,"Max Temp"] =weather_data['main'] ['temp_max']
        cities_pd.loc[index,"Wind Speed"] =weather_data['wind']['speed']
        print(f'Processing Record {city_cnt} of set {set_cnt} | {city}')
        
        # city cnt and set cnt rules
        if city_cnt<50:
            city_cnt += 1
        else:
            city_cnt = 1
            set_cnt += 1
        
    except (KeyError, IndexError):
        print ("City "+bcolors.BOLD + "not"+ bcolors.ENDC+" found. Skipping...")

# Show end of processing
print('-----------------------------------')
print('Data Retrieval Complete')
print('-----------------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------------
# Processing Record 1 of set 1 | naze
# Processing Record 2 of set 1 | alofi
# Processing Record 3 of set 1 | busselton
# Processing Record 4 of set 1 | rikitea
# Processing Record 5 of set 1 | cape town
# Processing Record 6 of set 1 | bluff
# City not found. Skipping...
# Processing Record 7 of set 1 | tasiilaq
# Processing Record 8 of set 1 | lebu
# City not found. Skipping...
# Processing Record 9 of set 1 | warrnambool
# Processing Record 10 of set 1 | codrington
# Processing Record 11 of set 1 | matamoros
# Processing Record 12 of set 1 | ponta do sol
# Processing Record 13 of set 1 | longyearbyen
# Processing Record 14 of set 1 | new norfolk
# Processing Record 15 of set 1 | kamaishi
# Processing Record 16 of set 1 | kamina
# Processing Record 17 of set 1 | constitucion
# Processing Record 18 of set 1 | butaritari
# Processing Record 19 of set 1 | qaanaaq
# Processing Record 20 of set 1 | ust-nera
# Processing Record 21 of set 1 | kahului
# Processing Record 22 of set 1 | sao filipe
# Processing Record 23 of set 1 | bredasdorp
# Processing Record 24 of set 1 | mar del plata
# Processing Record 25 of set 1 | jamestown
# Processing Record 26 of set 1 | kovernino
# Processing Record 27 of set 1 | fairbanks
# Processing Record 28 of set 1 | barrow
# Processing Record 29 of set 1 | avarua
# Processing Record 30 of set 1 | los llanos de aridane
# City not found. Skipping...
# Processing Record 31 of set 1 | hithadhoo
# Processing Record 32 of set 1 | pevek
# Processing Record 33 of set 1 | muros
# Processing Record 34 of set 1 | hobart
# Processing Record 35 of set 1 | kapaa
# Processing Record 36 of set 1 | pleasanton
# Processing Record 37 of set 1 | punta arenas
# Processing Record 38 of set 1 | saint anthony
# Processing Record 39 of set 1 | ushuaia
# Processing Record 40 of set 1 | arman
# Processing Record 41 of set 1 | buala
# Processing Record 42 of set 1 | atuona
# Processing Record 43 of set 1 | cherskiy
# Processing Record 44 of set 1 | natal
# Processing Record 45 of set 1 | tiksi
# Processing Record 46 of set 1 | yellowknife
# Processing Record 47 of set 1 | faanui
# Processing Record 48 of set 1 | hilo
# Processing Record 49 of set 1 | torbay
# Processing Record 50 of set 1 | coihaique
# Processing Record 1 of set 2 | sitka
# Processing Record 2 of set 2 | dibrugarh
# Processing Record 3 of set 2 | chokurdakh
# Processing Record 4 of set 2 | chuy
# Processing Record 5 of set 2 | san cristobal
# Processing Record 6 of set 2 | esperance
# Processing Record 7 of set 2 | tezu
# Processing Record 8 of set 2 | opuwo
# Processing Record 9 of set 2 | vaini
# Processing Record 10 of set 2 | cayenne
# City not found. Skipping...
# Processing Record 11 of set 2 | champerico
# Processing Record 12 of set 2 | klaksvik
# Processing Record 13 of set 2 | severo-kurilsk
# Processing Record 14 of set 2 | khatanga
# City not found. Skipping...
# Processing Record 15 of set 2 | guadalupe y calvo
# Processing Record 16 of set 2 | peterhead
# Processing Record 17 of set 2 | tautira
# Processing Record 18 of set 2 | pinehurst
# Processing Record 19 of set 2 | tabou
# Processing Record 20 of set 2 | mayo
# Processing Record 21 of set 2 | bolivar
# Processing Record 22 of set 2 | pietermaritzburg
# Processing Record 23 of set 2 | kuala pilah
# Processing Record 24 of set 2 | olden
# Processing Record 25 of set 2 | yeppoon
# Processing Record 26 of set 2 | katobu
# Processing Record 27 of set 2 | ponta delgada
# City not found. Skipping...
# Processing Record 28 of set 2 | grand gaube
# Processing Record 29 of set 2 | port hedland
# Processing Record 30 of set 2 | nabire
# Processing Record 31 of set 2 | phulabani
# Processing Record 32 of set 2 | port hardy
# Processing Record 33 of set 2 | puerto ayora
# Processing Record 34 of set 2 | bereda
# Processing Record 35 of set 2 | huarmey
# Processing Record 36 of set 2 | shiringushi
# Processing Record 37 of set 2 | marawi
# Processing Record 38 of set 2 | tarko-sale
# City not found. Skipping...
# Processing Record 39 of set 2 | albany
# Processing Record 40 of set 2 | tuatapere
# City not found. Skipping...
# Processing Record 41 of set 2 | kuching
# Processing Record 42 of set 2 | tiarei
# Processing Record 43 of set 2 | luderitz
# Processing Record 44 of set 2 | agen
# Processing Record 45 of set 2 | marystown
# Processing Record 46 of set 2 | cabo san lucas
# City not found. Skipping...
# Processing Record 47 of set 2 | kruisfontein
# Processing Record 48 of set 2 | sayyan
# Processing Record 49 of set 2 | acajutla
# Processing Record 50 of set 2 | dikson
# Processing Record 1 of set 3 | diego de almagro
# Processing Record 2 of set 3 | brae
# Processing Record 3 of set 3 | te anau
# Processing Record 4 of set 3 | madison
# Processing Record 5 of set 3 | bhinmal
# Processing Record 6 of set 3 | lorengau
# Processing Record 7 of set 3 | souillac
# Processing Record 8 of set 3 | saint-louis
# Processing Record 9 of set 3 | meulaboh
# Processing Record 10 of set 3 | fortuna foothills
# Processing Record 11 of set 3 | mataura
# Processing Record 12 of set 3 | puerto colombia
# Processing Record 13 of set 3 | berea
# Processing Record 14 of set 3 | zvishavane
# City not found. Skipping...
# Processing Record 15 of set 3 | kodiak
# Processing Record 16 of set 3 | port blair
# Processing Record 17 of set 3 | sampit
# Processing Record 18 of set 3 | ola
# Processing Record 19 of set 3 | port alfred
# Processing Record 20 of set 3 | tilichiki
# Processing Record 21 of set 3 | mahebourg
# Processing Record 22 of set 3 | airai
# Processing Record 23 of set 3 | kapit
# Processing Record 24 of set 3 | buraydah
# Processing Record 25 of set 3 | bima
# Processing Record 26 of set 3 | chacabuco
# Processing Record 27 of set 3 | pasighat
# Processing Record 28 of set 3 | camacha
# Processing Record 29 of set 3 | suoyarvi
# Processing Record 30 of set 3 | mukhtolovo
# Processing Record 31 of set 3 | avanigadda
# Processing Record 32 of set 3 | vardo
# Processing Record 33 of set 3 | touros
# Processing Record 34 of set 3 | erzin
# Processing Record 35 of set 3 | dalbandin
# Processing Record 36 of set 3 | atambua
# Processing Record 37 of set 3 | adrar
# Processing Record 38 of set 3 | katsuura
# Processing Record 39 of set 3 | kidal
# Processing Record 40 of set 3 | satao
# Processing Record 41 of set 3 | chaman
# Processing Record 42 of set 3 | san jose
# Processing Record 43 of set 3 | changli
# Processing Record 44 of set 3 | saskylakh
# City not found. Skipping...
# Processing Record 45 of set 3 | lima
# Processing Record 46 of set 3 | yarada
# Processing Record 47 of set 3 | dhidhdhoo
# Processing Record 48 of set 3 | sebeta
# City not found. Skipping...
# Processing Record 49 of set 3 | vao
# Processing Record 50 of set 3 | bowen
# Processing Record 1 of set 4 | hobyo
# Processing Record 2 of set 4 | morant bay
# Processing Record 3 of set 4 | padang
# Processing Record 4 of set 4 | kouroussa
# Processing Record 5 of set 4 | puerto madryn
# Processing Record 6 of set 4 | nkhotakota
# Processing Record 7 of set 4 | carnarvon
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of set 4 | ambilobe
# Processing Record 9 of set 4 | tuktoyaktuk
# Processing Record 10 of set 4 | hermanus
# Processing Record 11 of set 4 | sobolevo
# Processing Record 12 of set 4 | ilulissat
# Processing Record 13 of set 4 | inhambane
# Processing Record 14 of set 4 | georgetown
# Processing Record 15 of set 4 | orono
# Processing Record 16 of set 4 | kungurtug
# Processing Record 17 of set 4 | thompson
# Processing Record 18 of set 4 | aklavik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of set 4 | hambantota
# Processing Record 20 of set 4 | bethel
# Processing Record 21 of set 4 | siedlce
# Processing Record 22 of set 4 | calvia
# Processing Record 23 of set 4 | batsfjord
# Processing Record 24 of set 4 | namatanai
# Processing Record 25 of set 4 | cidreira
# Processing Record 26 of set 4 | scottsbluff
# Processing Record 27 of set 4 | narasannapeta
# Processing Record 28 of set 4 | dudinka
# Processing Record 29 of set 4 | saint george
# City not found. Skipping...
# Processing Record 30 of set 4 | kabardinka
# Processing Record 31 of set 4 | hovd
# Processing Record 32 of set 4 | olavarria
# Processing Record 33 of set 4 | walvis bay
# Processing Record 34 of set 4 | saldanha
# Processing Record 35 of set 4 | grand baie
# City not found. Skipping...
# Processing Record 36 of set 4 | atar
# Processing Record 37 of set 4 | poronaysk
# Processing Record 38 of set 4 | harqalah
# Processing Record 39 of set 4 | balad
# Processing Record 40 of set 4 | kaseda
# Processing Record 41 of set 4 | balkhash
# Processing Record 42 of set 4 | pereslavl-zalesskiy
# Processing Record 43 of set 4 | puerto leguizamo
# City not found. Skipping...
# Processing Record 44 of set 4 | gusau
# Processing Record 45 of set 4 | chunoyar
# Processing Record 46 of set 4 | onega
# Processing Record 47 of set 4 | lakselv
# City not found. Skipping...
# Processing Record 48 of set 4 | aldan
# Processing Record 49 of set 4 | saint-philippe
# Processing Record 50 of set 4 | viedma
# Processing Record 1 of set 5 | anadyr
# Processing Record 2 of set 5 | mount isa
# Processing Record 3 of set 5 | yulara
# Processing Record 4 of set 5 | lagoa
# Processing Record 5 of set 5 | hasaki
# Processing Record 6 of set 5 | tarsus
# Processing Record 7 of set 5 | east london
# Processing Record 8 of set 5 | nikolskoye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of set 5 | san angelo
# Processing Record 10 of set 5 | castro
# Processing Record 11 of set 5 | alice springs
# Processing Record 12 of set 5 | iqaluit
# Processing Record 13 of set 5 | bandarbeyla
# Processing Record 14 of set 5 | acapulco
# Processing Record 15 of set 5 | kawalu
# Processing Record 16 of set 5 | talnakh
# Processing Record 17 of set 5 | revda
# Processing Record 18 of set 5 | calama
# Processing Record 19 of set 5 | auki
# Processing Record 20 of set 5 | gilbues
# Processing Record 21 of set 5 | ayacucho
# Processing Record 22 of set 5 | navrongo
# Processing Record 23 of set 5 | gwadar
# Processing Record 24 of set 5 | ushtobe
# Processing Record 25 of set 5 | upernavik
# Processing Record 26 of set 5 | merauke
# Processing Record 27 of set 5 | lucapa
# Processing Record 28 of set 5 | vila franca do campo
# Processing Record 29 of set 5 | rio gallegos
# Processing Record 30 of set 5 | emba
# City not found. Skipping...
# Processing Record 31 of set 5 | skibbereen
# Processing Record 32 of set 5 | emerald
# Processing Record 33 of set 5 | mount gambier
# City not found. Skipping...
# Processing Record 34 of set 5 | havre-saint-pierre
# Processing Record 35 of set 5 | norman wells
# Processing Record 36 of set 5 | lata
# Processing Record 37 of set 5 | margate
# Processing Record 38 of set 5 | port lincoln
# Processing Record 39 of set 5 | kondinskoye
# Processing Record 40 of set 5 | fort nelson
# Processing Record 41 of set 5 | ostrovnoy
# Processing Record 42 of set 5 | amapa
# Processing Record 43 of set 5 | broken hill
# Processing Record 44 of set 5 | half moon bay
# Processing Record 45 of set 5 | yashkul
# Processing Record 46 of set 5 | burgeo
# Processing Record 47 of set 5 | prestea
# Processing Record 48 of set 5 | denia
# Processing Record 49 of set 5 | ryotsu
# Processing Record 50 of set 5 | faya
# Processing Record 1 of set 6 | kaitangata
# Processing Record 2 of set 6 | liku
# Processing Record 3 of set 6 | sobreira
# City not found. Skipping...
# Processing Record 4 of set 6 | ancud
# Processing Record 5 of set 6 | lerwick
# Processing Record 6 of set 6 | fukue
# City not found. Skipping...
# Processing Record 7 of set 6 | victoria
# Processing Record 8 of set 6 | ahuimanu
# Processing Record 9 of set 6 | teguise
# Processing Record 10 of set 6 | kavieng
# Processing Record 11 of set 6 | mandan
# Processing Record 12 of set 6 | san patricio
# Processing Record 13 of set 6 | bintulu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of set 6 | henties bay
# Processing Record 15 of set 6 | harper
# Processing Record 16 of set 6 | lubana
# Processing Record 17 of set 6 | ngunguru
# Processing Record 18 of set 6 | aswan
# Processing Record 19 of set 6 | provideniya
# Processing Record 20 of set 6 | mehamn
# Processing Record 21 of set 6 | salalah
# Processing Record 22 of set 6 | isangel
# Processing Record 23 of set 6 | ialibu
# Processing Record 24 of set 6 | north bend
# Processing Record 25 of set 6 | narsaq
# Processing Record 26 of set 6 | simao
# Processing Record 27 of set 6 | brainerd
# City not found. Skipping...
# Processing Record 28 of set 6 | malayal
# Processing Record 29 of set 6 | necochea
# Processing Record 30 of set 6 | burnie
# Processing Record 31 of set 6 | wolgast
# Processing Record 32 of set 6 | quanzhou
# Processing Record 33 of set 6 | sola
# Processing Record 34 of set 6 | skibotn
# Processing Record 35 of set 6 | ondjiva
# Processing Record 36 of set 6 | mangan
# Processing Record 37 of set 6 | katherine
# Processing Record 38 of set 6 | awbari
# City not found. Skipping...
# Processing Record 39 of set 6 | srednekolymsk
# Processing Record 40 of set 6 | kloulklubed
# Processing Record 41 of set 6 | bealanana
# Processing Record 42 of set 6 | mahanoro
# City not found. Skipping...
# Processing Record 43 of set 6 | tambacounda
# Processing Record 44 of set 6 | port elizabeth
# Processing Record 45 of set 6 | virginia beach
# Processing Record 46 of set 6 | lethem
# City not found. Skipping...
# Processing Record 47 of set 6 | puerto escondido
# Processing Record 48 of set 6 | jinchang
# Processing Record 49 of set 6 | hofn
# Processing Record 50 of set 6 | arraial do cabo
# Processing Record 1 of set 7 | bubaque
# Processing Record 2 of set 7 | saint-augustin
# City not found. Skipping...
# Processing Record 3 of set 7 | hirara
# Processing Record 4 of set 7 | caarapo
# City not found. Skipping...
# Processing Record 5 of set 7 | aykhal
# Processing Record 6 of set 7 | rendsburg
# Processing Record 7 of set 7 | ivoti
# Processing Record 8 of set 7 | beausejour
# City not found. Skipping...
# Processing Record 9 of set 7 | the valley
# Processing Record 10 of set 7 | palmer
# Processing Record 11 of set 7 | vaitape
# City not found. Skipping...
# Processing Record 12 of set 7 | candolim
# Processing Record 13 of set 7 | samarinda
# Processing Record 14 of set 7 | russell
# Processing Record 15 of set 7 | gambela
# Processing Record 16 of set 7 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 17 of set 7 | tazovskiy
# Processing Record 18 of set 7 | begoro
# Processing Record 19 of set 7 | san pedro
# Processing Record 20 of set 7 | camden
# Processing Record 21 of set 7 | shingu
# Processing Record 22 of set 7 | turka
# Processing Record 23 of set 7 | banda aceh
# Processing Record 24 of set 7 | homer
# Processing Record 25 of set 7 | abha
# Processing Record 26 of set 7 | leh
# Processing Record 27 of set 7 | tromso
# Processing Record 28 of set 7 | la ronge
# Processing Record 29 of set 7 | sioux lookout
# Processing Record 30 of set 7 | pagudpud
# City not found. Skipping...
# Processing Record 31 of set 7 | krizevci
# Processing Record 32 of set 7 | paris
# Processing Record 33 of set 7 | cristalina
# Processing Record 34 of set 7 | port-cartier
# City not found. Skipping...
# Processing Record 35 of set 7 | waipawa
# Processing Record 36 of set 7 | okha
# Processing Record 37 of set 7 | dingle
# Processing Record 38 of set 7 | komsomolskiy
# Processing Record 39 of set 7 | petukhovo
# Processing Record 40 of set 7 | mingaora
# City not found. Skipping...
# Processing Record 41 of set 7 | bradford
# Processing Record 42 of set 7 | hastings
# Processing Record 43 of set 7 | leningradskiy
# Processing Record 44 of set 7 | bambous virieux
# Processing Record 45 of set 7 | general cepeda
# Processing Record 46 of set 7 | huilong
# City not found. Skipping...
# Processing Record 47 of set 7 | macas
# Processing Record 48 of set 7 | pori
# Processing Record 49 of set 7 | jombang
# Processing Record 50 of set 7 | sao joao da barra
# Processing Record 1 of set 8 | taoudenni
# Processing Record 2 of set 8 | mogadishu
# Processing Record 3 of set 8 | coquimbo
# Processing Record 4 of set 8 | sao gabriel da cachoeira
# Processing Record 5 of set 8 | cabedelo
# Processing Record 6 of set 8 | mina
# Processing Record 7 of set 8 | moose factory
# Processing Record 8 of set 8 | teixeira
# Processing Record 9 of set 8 | ukiah
# Processing Record 10 of set 8 | biloela
# Processing Record 11 of set 8 | altamira
# Processing Record 12 of set 8 | trindade
# Processing Record 13 of set 8 | kaeo
# Processing Record 14 of set 8 | cairns
# Processing Record 15 of set 8 | cuenca
# Processing Record 16 of set 8 | berlevag
# Processing Record 17 of set 8 | sawakin
# Processing Record 18 of set 8 | pisco
# Processing Record 19 of set 8 | grants pass
# Processing Record 20 of set 8 | salinopolis
# Processing Record 21 of set 8 | vostok
# Processing Record 22 of set 8 | francisco beltrao
# Processing Record 23 of set 8 | puri
# Processing Record 24 of set 8 | fortuna
# Processing Record 25 of set 8 | tukums
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of set 8 | xinqing
# Processing Record 27 of set 8 | nemuro
# Processing Record 28 of set 8 | aripuana
# Processing Record 29 of set 8 | kirakira
# Processing Record 30 of set 8 | ureshino
# Processing Record 31 of set 8 | basco
# Processing Record 32 of set 8 | price
# Processing Record 33 of set 8 | pacasmayo
# Processing Record 34 of set 8 | hildburghausen
# Processing Record 35 of set 8 | quatre cocos
# Processing Record 36 of set 8 | helong
# Processing Record 37 of set 8 | conceicao da barra
# Processing Record 38 of set 8 | bakel
# Processing Record 39 of set 8 | mangrol
# Processing Record 40 of set 8 | akcakoca
# Processing Record 41 of set 8 | bijie
# Processing Record 42 of set 8 | avera
# Processing Record 43 of set 8 | bundaberg
# City not found. Skipping...
# Processing Record 44 of set 8 | nishihara
# Processing Record 45 of set 8 | miyako
# Processing Record 46 of set 8 | khasan
# Processing Record 47 of set 8 | goianesia
# Processing Record 48 of set 8 | bouna
# Processing Record 49 of set 8 | ha tinh
# Processing Record 50 of set 8 | sorland
# City not found. Skipping...
# Processing Record 1 of set 9 | monte santo
# Processing Record 2 of set 9 | nhamunda
# Processing Record 3 of set 9 | sujiatun
# Processing Record 4 of set 9 | praia da vitoria
# City not found. Skipping...
# Processing Record 5 of set 9 | skala
# Processing Record 6 of set 9 | xuanhua
# Processing Record 7 of set 9 | bend
# Processing Record 8 of set 9 | ribeira grande
# Processing Record 9 of set 9 | kampot
# Processing Record 10 of set 9 | caravelas
# Processing Record 11 of set 9 | oranjemund
# Processing Record 12 of set 9 | nara
# Processing Record 13 of set 9 | shihezi
# Processing Record 14 of set 9 | murgab
# Processing Record 15 of set 9 | timbiras
# Processing Record 16 of set 9 | salekhard
# Processing Record 17 of set 9 | bodden town
# Processing Record 18 of set 9 | najran
# Processing Record 19 of set 9 | lompoc
# Processing Record 20 of set 9 | nantucket
# Processing Record 21 of set 9 | bontang
# Processing Record 22 of set 9 | balkanabat
# Processing Record 23 of set 9 | chongwe
# Processing Record 24 of set 9 | ekibastuz
# Processing Record 25 of set 9 | pak phanang
# Processing Record 26 of set 9 | anloga
# Processing Record 27 of set 9 | west odessa
# Processing Record 28 of set 9 | kamienna gora
# Processing Record 29 of set 9 | sakaiminato
# Processing Record 30 of set 9 | lasa
# Processing Record 31 of set 9 | tefe
# Processing Record 32 of set 9 | arica
# Processing Record 33 of set 9 | kingaroy
# Processing Record 34 of set 9 | charleston
# Processing Record 35 of set 9 | kunming
# City not found. Skipping...
# Processing Record 36 of set 9 | geraldton
# Processing Record 37 of set 9 | zyryanka
# Processing Record 38 of set 9 | yokosuka
# Processing Record 39 of set 9 | sinnamary
# Processing Record 40 of set 9 | ixtapa
# Processing Record 41 of set 9 | nanortalik
# Processing Record 42 of set 9 | asyut
# Processing Record 43 of set 9 | makakilo city
# Processing Record 44 of set 9 | chikwawa
# Processing Record 45 of set 9 | abeche
# Processing Record 46 of set 9 | csemo
# Processing Record 47 of set 9 | boueni
# Processing Record 48 of set 9 | aksu
# Processing Record 49 of set 9 | ulladulla
# Processing Record 50 of set 9 | hailar
# Processing Record 1 of set 10 | gushikawa
# Processing Record 2 of set 10 | inuvik
# Processing Record 3 of set 10 | beitbridge
# Processing Record 4 of set 10 | tungor
# Processing Record 5 of set 10 | yenagoa
# Processing Record 6 of set 10 | imbituba
# Processing Record 7 of set 10 | ndioum
# Processing Record 8 of set 10 | obernai
# Processing Record 9 of set 10 | san lawrenz
# City not found. Skipping...
# Processing Record 10 of set 10 | kirs
# City not found. Skipping...
# Processing Record 11 of set 10 | sabha
# City not found. Skipping...
# Processing Record 12 of set 10 | picton
# Processing Record 13 of set 10 | jardim
# Processing Record 14 of set 10 | coahuayana
# City not found. Skipping...
# Processing Record 15 of set 10 | jardim do serido
# Processing Record 16 of set 10 | west wendover
# Processing Record 17 of set 10 | ketchikan
# Processing Record 18 of set 10 | grindavik
# City not found. Skipping...
# Processing Record 19 of set 10 | san jacinto
# Processing Record 20 of set 10 | griffith
# Processing Record 21 of set 10 | manggar
# Processing Record 22 of set 10 | nauta
# Processing Record 23 of set 10 | novyy buh
# Processing Record 24 of set 10 | itarema
# Processing Record 25 of set 10 | flinders
# Processing Record 26 of set 10 | goma
# Processing Record 27 of set 10 | det udom
# Processing Record 28 of set 10 | saint-paul
# Processing Record 29 of set 10 | naliya
# Processing Record 30 of set 10 | buena vista
# Processing Record 31 of set 10 | tual
# Processing Record 32 of set 10 | kutum
# City not found. Skipping...
# Processing Record 33 of set 10 | dosso
# Processing Record 34 of set 10 | bathsheba
# Processing Record 35 of set 10 | flin flon
# Processing Record 36 of set 10 | fortaleza
# Processing Record 37 of set 10 | yagodnoye
# Processing Record 38 of set 10 | ono
# Processing Record 39 of set 10 | spassk
# Processing Record 40 of set 10 | berezovka
# City not found. Skipping...
# Processing Record 41 of set 10 | martapura
# Processing Record 42 of set 10 | chinhoyi
# City not found. Skipping...
# Processing Record 43 of set 10 | nieves
# Processing Record 44 of set 10 | lahore
# Processing Record 45 of set 10 | ucluelet
# Processing Record 46 of set 10 | ibra
# Processing Record 47 of set 10 | chumikan
# Processing Record 48 of set 10 | zhigansk
# Processing Record 49 of set 10 | mitsamiouli
# Processing Record 50 of set 10 | abonnema
# City not found. Skipping...
# Processing Record 1 of set 11 | maniitsoq
# Processing Record 2 of set 11 | abu samrah
# Processing Record 3 of set 11 | zeya
# City not found. Skipping...
# Processing Record 4 of set 11 | barranca de upia
# Processing Record 5 of set 11 | ramanuj ganj
# Processing Record 6 of set 11 | esna
# Processing Record 7 of set 11 | tabory
# Processing Record 8 of set 11 | george
# Processing Record 9 of set 11 | aberdeen
# Processing Record 10 of set 11 | rabat
# Processing Record 11 of set 11 | shahpur
# Processing Record 12 of set 11 | yining
# Processing Record 13 of set 11 | paso de los toros
# Processing Record 14 of set 11 | sulangan
# Processing Record 15 of set 11 | springfield
# Processing Record 16 of set 11 | hamilton
# Processing Record 17 of set 11 | pouebo
# Processing Record 18 of set 11 | kharitonovo
# Processing Record 19 of set 11 | hualmay
# Processing Record 20 of set 11 | lyubim
# Processing Record 21 of set 11 | taksimo
# Processing Record 22 of set 11 | abilene
# City not found. Skipping...
# Processing Record 23 of set 11 | orikhove
# Processing Record 24 of set 11 | davidson
# City not found. Skipping...
# Processing Record 25 of set 11 | piura
# Processing Record 26 of set 11 | barraute
# Processing Record 27 of set 11 | buin
# Processing Record 28 of set 11 | pakenham
# Processing Record 29 of set 11 | antofagasta
# Processing Record 30 of set 11 | pozo colorado
# Processing Record 31 of set 11 | panama city
# Processing Record 32 of set 11 | moussoro
# Processing Record 33 of set 11 | surt
# Processing Record 34 of set 11 | clyde river
# Processing Record 35 of set 11 | ritchie
# Processing Record 36 of set 11 | dharchula
# Processing Record 37 of set 11 | ferrara
# Processing Record 38 of set 11 | rumphi
# Processing Record 39 of set 11 | golyshmanovo
# City not found. Skipping...
# Processing Record 40 of set 11 | erice
# Processing Record 41 of set 11 | mahajanga
# Processing Record 42 of set 11 | haines junction
# Processing Record 43 of set 11 | mujiayingzi
# Processing Record 44 of set 11 | rivera
# Processing Record 45 of set 11 | hun
# City not found. Skipping...
# Processing Record 46 of set 11 | chifeng
# -----------------------------------
# Data Retrieval Complete
# -----------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export to .csv
cities_pd.to_csv(output_data_file)

# Display data frame
cities_pd.count()
# Out:
# City          607
# Cloudiness    607
# Country       607
# Date          607
# Humidity      607
# Lat           607
# Lng           607
# Max Temp      607
# Wind Speed    607
# dtype: int64

# %%
# Visualise data
cities_pd.head()
# Out:
#         City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0       naze        100      NG  1562898416       97   5.43    7.07  295.174
# 1      alofi         75      NU  1562898350       78 -19.06 -169.92   300.15
# 2  busselton        100      AU  1562898517       61 -33.64  115.35   288.15
# 3    rikitea          0      PF  1562898143       81 -23.12 -134.97  296.124
# 4  cape town         75      ZA  1562898001       93 -33.93   18.42   286.48
#
#   Wind Speed
# 0       2.62
# 1        6.2
# 2       3.26
# 3        6.4
# 4        4.6

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x = pd.to_numeric(cities_pd['Lat'])
y = cities_pd['Max Temp']

plt.scatter(x, y, marker="o" ,  edgecolors="black", c='skyblue', alpha =0.85, linewidth=[0.79])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature (07/11/19)')

plt.grid()
plt.show()

# Save Figure
plt.savefig('W1.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# x = pd.to_numeric(cities_pd['Lat'])
y = cities_pd['Humidity']

plt.scatter(x, y, marker="o" ,  edgecolors="black", c='skyblue', alpha =0.85, linewidth=[0.79])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (07/11/19)')

plt.grid()
plt.show()

# Save Figure
plt.savefig('W2.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# x = pd.to_numeric(cities_pd['Lat'])
y = cities_pd['Cloudiness']

plt.scatter(x, y, marker="o" ,  edgecolors="black", c='skyblue', alpha =0.85, linewidth=[0.79])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (07/11/19)')

plt.grid()
plt.show()

# Save Figure
plt.savefig('W3.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# x = pd.to_numeric(cities_pd['Lat'])
y = cities_pd['Wind Speed']

plt.scatter(x, y, marker="o" ,  edgecolors="black", c='skyblue', alpha =0.85, linewidth=[0.79])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed (07/11/19)')

plt.grid()
plt.show()

# Save Figure
plt.savefig('W4.png')
